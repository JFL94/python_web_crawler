# %%
print("Hello python!")
# Out:
# Hello python!

# %% [markdown]
# ### 運算子介紹

# %%
# 內建函式 print()
print(5 + 8)
print(90 - 10)
print(4 * 7)
print(7 / 2)
print(7 // 2)
print(7 % 3)
print(3 ** 4)
print(99 ** 99)
# Out:
# 13
# 80
# 28
# 3.5
# 3
# 1
# 81
# 369729637649726772657187905628805440595668764281741102430259972423552570455277523421410650010128232727940978889548326540119429996769494359451621570193644014418071060667659301384999779999159200499899

# %% [markdown]
# ### 運算子優先順序

# %%
78 + 95 + 83 + 69 + 70
# Out:
# 395

# %%
2+3*4
# Out:
# 14

# %%
(2+3)*4
# Out:
# 20

# %%
2 * (1 + 2) ** 2 - 2 ** 2 * 2
# Out:
# 10

# %% [markdown]
# ### python 的基本資料型別

# %%
# int
5
15
# Out:
# 15

# %%
# float
5.0
# Out:
# 5.0

# %%
# str
"5"
'5'
# Out:
# '5'

# %%
# bool
True
False
# Out:
# False

# %%
5 + 5
# Out:
# 10

# %%
5 + 5.0
# Out:
# 10.0

# %%
# 內建函式 int() 轉整數
5 + int('5')
# Out:
# 10

# %%
#運算式(expression)，記憶體不會儲存
2 * (1 + 2) ** 2 - 2 ** 2 * 2

#敘述式(statement)，每一行程式皆是敘述式，把運算式值存到變數value，ram記憶體把value儲存起來
value = 2 * (1 + 2) ** 2 - 2 ** 2 * 2 

value #運算式
# Out:
# 10

# %%
#敘述式練習
chinese = 78
chinese = chinese + 5
english = 92
math = 67

total = chinese + english + math

average = total / 3
average
# Out:
# 80.66666666666667

# %%
# 數值與數學模組 math函式庫 
import math

# 複合指定運算子
chinese = 78
chinese += 5
chinese *= 10

# math函式庫squrt() chinese 開平方根 
value = math.sqrt(chinese)

# 內建函式 round() 四捨五入
value = round(value,ndigits=2)
print(value)

#先開平方根在四捨五入最後把值傳出並存在value變數
value = round(math.sqrt(chinese),ndigits=2)

print(value)
# Out:
# 28.81
# 28.81

# %%
# prompt1:python如何開平方根，請給我小範例
# prompt2:np.sqrt()請給我說明書
# prompt3:python的數學運算子有哪些?
# prompt4:請依照這個ipynb，幫我出一題題目(對象是沒有python基礎的學生)

# %% [markdown]
# 練習題：計算體重指數 BMI
# BMI（Body Mass Index，身體質量指數）是評估體重是否健康的常用指標。
#
# 計算公式：
# BMI = 體重(公斤) ÷ 身高(公尺)²
#
# 題目要求：
#
# 建立變數 weight 儲存體重 72 公斤
# 建立變數 height 儲存身高 175 公分（注意：公式需要公尺，請先除以 100）
# 使用 ** 運算子計算身高的平方
# 計算 BMI 值並儲存在變數 bmi 中
# 使用 round() 函式將 BMI 四捨五入到小數點後 2 位
# 印出結果
# 參考輸出：
# 23.35
#
# 提示：
#
# 身高需轉換成公尺：height = 175 / 100
# 平方使用 ** 運算子：height ** 2
# 四捨五入：round(bmi, 2)

# %%
# 請在此處撰寫你的程式碼
weight = 72
height = 175
bmi = weight / (height/100) ** 2
print(round(bmi,2))
# Out:
# 23.51
